# %% [markdown]
# # Week 2 Checkpoint: First Data Profile
# **BAN 6003 Data Management and Analytics Integration**
#
# Complete this notebook using the `employee_data.csv` file in the `data/` folder.
#
# This is the independent checkpoint for Week 2. Use the functions practiced in the guided lab. You are not expected to clean the data yet. Your goal is to profile the data and report what you notice.

# %% [markdown]
# ## Instructions
#
# 1. Run each cell from top to bottom.
# 2. Fill in all cells marked `# Your code here`.
# 3. Write short answers in the markdown response areas.
# 4. Save, commit, and push your notebook to GitHub.
#
# You may use the Week 2 guided lab as a reference.

# %% [markdown]
# ## Task 0: Import Pandas and Load the Data
# Run the cell below.

# %%
import pandas as pd

df = pd.read_csv("../data/employee_data.csv")
df.head()
# Out:
#   employee_id first_name last_name hire_date   department  salary   age  \
# 0         101       John     Smith   4/15/22    Marketing   85000  34.0
# 1         102       Jane       Doe   8/20/21        Sales   92000  45.0
# 2         103      Peter     Jones    1/2/22           HR   71000  29.0
# 3         104       Mary   Johnson  11/10/23  Engineering  115000  38.0
# 4         105       Mike     Brown   5/30/20        sales   89000   NaN
#
#   full_time
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False

# %% [markdown]
# ## Task 1: Basic Structure
# Show the basic structure of the DataFrame.
#
# Your code should show:
# - the shape of the DataFrame;
# - the column names;
# - the first five rows;
# - the last five rows.

# %%
# shape
print("Shape of the dataset (rows, columns):")
print(df.shape)
print()
# column names
print("Column names:")
print(df.columns)
print()
# first 5 rows
print("First 5 rows:")
print(df.head())
print()
# last 5 rows
print("Last 5 rows:")
print(df.tail())
# Out:
# Shape of the dataset (rows, columns):
# (13, 8)
#
# Column names:
# Index(['employee_id', 'first_name', 'last_name', 'hire_date', 'department',
#        'salary', 'age', 'full_time'],
#       dtype='str')
#
# First 5 rows:
#   employee_id first_name last_name hire_date   department  salary   age  \
# 0         101       John     Smith   4/15/22    Marketing   85000  34.0
# 1         102       Jane       Doe   8/20/21        Sales   92000  45.0
# 2         103      Peter     Jones    1/2/22           HR   71000  29.0
# 3         104       Mary   Johnson  11/10/23  Engineering  115000  38.0
# 4         105       Mike     Brown   5/30/20        sales   89000   NaN
#
#   full_time
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#
# Last 5 rows:
#    employee_id first_name last_name hire_date   department    salary    age  \
# 8          102      Emily     White   1/15/24        Sales     91000   31.0
# 9          110      David    Miller   7/22/19           HR     68000   58.0
# 10         111      Sarah     Moore   3/12/23    Marketing  $91,000    28.0
# 11       error      Kevin     Clark    2/5/24        Sales     88000   35.0
# 12         113      Brian      Hall   6/18/22  Engineering   5900000  999.0
#
#    full_time
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True

# %% [markdown]
# ### Task 1 Written Response
# Write 1–2 sentences describing the size and general structure of the dataset.
#
# **Your response:**
# The dataset is comprised of a 13 row 8 column list that shows employee information. Some data is missing, duplicate or in error. The dataset is not cleaned or ready for analysis.

# %% [markdown]
# ## Task 2: Data Types and Non-Missing Counts
# Use Pandas to inspect data types and non-missing counts.
#
# Your code should use:
# - `info()`
# - `dtypes`

# %%
# info
print("Dataset with non-missing counts:")
print(df.info())
print()
# data types
print("Data types of each column:")
print(df.dtypes)
# Out:
# Dataset with non-missing counts:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  13 non-null     str
#  1   first_name   13 non-null     str
#  2   last_name    13 non-null     str
#  3   hire_date    12 non-null     str
#  4   department   13 non-null     str
#  5   salary       12 non-null     str
#  6   age          12 non-null     float64
#  7   full_time    12 non-null     object
# dtypes: float64(1), object(1), str(6)
# memory usage: 964.0+ bytes
# None
#
# Data types of each column:
# employee_id        str
# first_name         str
# last_name          str
# hire_date          str
# department         str
# salary             str
# age            float64
# full_time       object
# dtype: object

# %% [markdown]
# ### Task 2 Written Response
# Which columns, if any, have data types that might need to be investigated later? For example, is a number or date stored as text/object?
#
# **Your response:**
# The following data types need to be investigated further (employee_id, hire_data, salary, age, full_time).

# %% [markdown]
# ## Task 3: Missing Values
# Check missing values for all columns.
#
# Your code should use `isna().sum()`.
#
# Optional: also calculate missing percentages.

# %%
# missing values for all columns
print("Missing values for each column:")
print(df.isnull().sum())

# this doesn't highlight the employee_id column with the "error" value for Kevin Clark
# Out:
# Missing values for each column:
# employee_id    0
# first_name     0
# last_name      0
# hire_date      1
# department     0
# salary         1
# age            1
# full_time      1
# dtype: int64

# %% [markdown]
# ### Task 3 Written Response
# Which columns have missing values? Which missing values seem most important to investigate later?
#
# **Your response:**
# The columns with missing values are the hire_date, salary, age, and full_time. As noted in the above code block, the employee_id column has an error value that also represents a missing value. Of all of these, I'm most concerned with the salary and age. These topics are related to benefits.

# %% [markdown]
# ## Task 4: Numerical Summary
# Use `.describe()` to summarize numerical columns.
#
# Then choose one numerical column and calculate at least two individual summary statistics such as mean, median, min, max, or standard deviation.

# %%
#  descriptive statistics for all columns; ****shows which columns are numeric and which are categorical****
print("Descriptive statistics for all columns:")
print(df.describe(include="all"))
print()
# descriptive statistics for numerical columns
print("Descriptive statistics for numerical columns:")
print(df.describe())
print()
# alternatively
print("Column name: age")
print("Count:", df["age"].count())
print("Mean:", df["age"].mean())
print("Median:", df["age"].median())
print("Minimum:", df["age"].min())
print("Maximum:", df["age"].max())
print("Standard deviation:", df["age"].std())
# Out:
# Descriptive statistics for all columns:
#        employee_id first_name last_name hire_date department salary  \
# count           13         13        13        12         13     12
# unique          12         13        13        12          5     12
# top            102       John     Smith   4/15/22      Sales  85000
# freq             2          1         1         1          4      1
# mean           NaN        NaN       NaN       NaN        NaN    NaN
# std            NaN        NaN       NaN       NaN        NaN    NaN
# min            NaN        NaN       NaN       NaN        NaN    NaN
# 25%            NaN        NaN       NaN       NaN        NaN    NaN
# 50%            NaN        NaN       NaN       NaN        NaN    NaN
# 75%            NaN        NaN       NaN       NaN        NaN    NaN
# max            NaN        NaN       NaN       NaN        NaN    NaN
#
#                age full_time
# count    12.000000        12
# unique         NaN         2
# top            NaN      True
# freq           NaN        11
# mean    118.583333       NaN
# std     277.411889       NaN
# min      28.000000       NaN
# 25%      32.500000       NaN
# 50%      36.500000       NaN
# 75%      46.750000       NaN
# max     999.000000       NaN
#
# Descriptive statistics for numerical columns:
#               age
# count   12.000000
# mean   118.583333
# std    277.411889
# min     28.000000
# 25%     32.500000
# 50%     36.500000
# 75%     46.750000
# max    999.000000
#
# Column name: age
# Count: 12
# Mean: 118.58333333333333
# Median: 36.5
# Minimum: 28.0
# Maximum: 999.0
# Standard deviation: 277.41188882347143

# %% [markdown]
# ### Task 4 Written Response
# What do you notice from the numerical summaries? Mention at least one range, unusual value, or pattern.
#
# **Your response:**
# Columns that are not fully numerical or have entries that are listed as strings (when they should be numerical) are highlighted. Example, the salary column should also be calculated and because values are not listed as numbers, it does not compute. The age with a max of 999 is a problem and needs to be looked at. The salary for Brian Hall should show as a max of 5,900,000 and stick out as anomalous as well.

# %% [markdown]
# ## Task 5: Categorical Summary
# Use `.value_counts()` to summarize at least one categorical column.
#
# Start with `department` if it exists in the dataset. Then choose one additional categorical column if available.

# %%
# categorical summary for one categorical column
print("Categorical summary for department column:")
print(df["department"].value_counts())
print()


print(df["employee_id"].value_counts())
print()
print(df["first_name"].value_counts())
print()
print(df["last_name"].value_counts())
print()
print(df["hire_date"].value_counts())
print()
print(df["salary"].value_counts())
print()
print(df["age"].value_counts())
print()
print(df["full_time"].value_counts())
# Out:
# Categorical summary for department column:
# department
# Sales          4
# Marketing      3
# Engineering    3
# HR             2
# sales          1
# Name: count, dtype: int64
#
# employee_id
# 102      2
# 101      1
# 103      1
# 104      1
# 105      1
# 106      1
# 107      1
# 108      1
# 110      1
# 111      1
# error    1
# 113      1
# Name: count, dtype: int64
#
# first_name
# John     1
# Jane     1
# Peter    1
# Mary     1
# Mike     1
# Susan    1
# Chris    1
# Laura    1
# Emily    1
# David    1
# Sarah    1
# Kevin    1
# Brian    1
# Name: count, dtype: int64
#
# last_name
# Smith      1
# Doe        1
# Jones      1
# Johnson    1
# Brown      1
# Davis      1
# Wilson     1
# Taylor     1
# White      1
# Miller     1
# Moore      1
# Clark      1
# Hall       1
# Name: count, dtype: int64
#
# hire_date
# 4/15/22        1
# 8/20/21        1
# 1/2/22         1
# 11/10/23       1
# 5/30/20        1
# 2023-FEB-21    1
# 9/1/21         1
# 1/15/24        1
# 7/22/19        1
# 3/12/23        1
# 2/5/24         1
# 6/18/22        1
# Name: count, dtype: int64
#
# salary
# 85000       1
# 92000       1
# 71000       1
# 115000      1
# 89000       1
# 95000       1
# 120000      1
# 91000       1
# 68000       1
# $91,000     1
# 88000       1
# 5900000     1
# Name: count, dtype: int64
#
# age
# 34.0     1
# 45.0     1
# 29.0     1
# 38.0     1
# 41.0     1
# 33.0     1
# 52.0     1
# 31.0     1
# 58.0     1
# 28.0     1
# 35.0     1
# 999.0    1
# Name: count, dtype: int64
#
# full_time
# True     11
# False     1
# Name: count, dtype: int64

# %% [markdown]
# ### Task 5 Written Response
# What are the most common categories? Do you notice anything that might need standardization or further investigation later?
#
# **Your response:**
# The most common data types are strings. This is making more fo the columns that would typically be numerical be classified as categorical. I would look at how the entries are entered and stored and change those to the same types first.

# %% [markdown]
# ## Task 6: Duplicate Checks
# Check for duplicate records and duplicate employee IDs.
#
# Your code should check:
# - fully duplicated rows;
# - duplicate `employee_id` values;
# - the most common `employee_id` values using `value_counts()`.

# %%
# Count fully duplicated rows
full_duplicate_rows = df.duplicated().sum()
print(f"Number of fully duplicated rows: {full_duplicate_rows}")
print()

# Count duplicate employee IDs
employee_id_duplicates = df["employee_id"].duplicated().sum()
print(f"Number of duplicated employee_id values after the first occurrence: {employee_id_duplicates}")
print()

print(df["employee_id"].value_counts(dropna=False).head(13))
# Out:
# Number of fully duplicated rows: 0
#
# Number of duplicated employee_id values after the first occurrence: 1
#
# employee_id
# 102      2
# 101      1
# 103      1
# 104      1
# 105      1
# 106      1
# 107      1
# 108      1
# 110      1
# 111      1
# error    1
# 113      1
# Name: count, dtype: int64

# %% [markdown]
# ### Task 6 Written Response
# Are there duplicate employee IDs? If yes, what might that mean if `employee_id` is supposed to uniquely identify each employee?
#
# **Your response:**
# There are duplicate employee id's and a single "error" entry. The duplicate can be a re-issue of a number that should not be allowed or a possible typo. The error value could be an entry or a value auto-populated. That too, would require inspection.

# %% [markdown]
# ## Task 7: Overall Data Quality Observations
# Write 3–5 bullet points summarizing the condition of the dataset.
#
# Focus on what you found from profiling. Do **not** clean the data yet.
#
# Examples:
# - The dataset has ___ rows and ___ columns.
# - The ___ column has missing values.
# - The ___ column may have an incorrect data type.
# - The ___ column has possible duplicate IDs.
# - The ___ column has a range from ___ to ___.

# %% [markdown]
# **Your observations:**
#
# 1. The dataset has _13_ rows and _8_ columns.
# 2. The _hire_date, salary, age, and full_time_ columns have missing values.
# 3. The _salary_ column may have an incorrect data type.
# 4. The _employee_id_ column has possible duplicate IDs.
# 5. The _age_ column has a range from _28_ to _999_.

# %% [markdown]
# ## Submission Checklist
# Before submitting, make sure:
#
# - [ ] All code cells run without errors.
# - [ ] You completed all tasks.
# - [ ] You wrote short responses in the markdown cells.
# - [ ] You saved the notebook.
# - [ ] You committed and pushed your work to GitHub.
#
# Use the terminal:
#
# ```bash
# git add .
# git commit -m "Completed Week 2 data profile checkpoint"
# git push
# ```
